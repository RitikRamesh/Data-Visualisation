# %% [markdown]
# # Plotting with ```matplotlib```
#
# ```matplotlib``` is a python library. It contains the ```pyplot``` module, which is basically a collection of functions such as ```plot```, ```title```, ```show()``` etc. ```pyplot``` is one of the most commonly used module for creating a variety of plots such as line plots, bar plots, histograms etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <font size = 6>plotting two 1-D numpy arrays</font>

# %%
x = np.linspace(5,100,25)
y = np.linspace(10,1000,25)
plt.plot(x,y)
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('First Plot')
plt.show()

# %%
x
# Out:
# array([  5.        ,   8.95833333,  12.91666667,  16.875     ,
#         20.83333333,  24.79166667,  28.75      ,  32.70833333,
#         36.66666667,  40.625     ,  44.58333333,  48.54166667,
#         52.5       ,  56.45833333,  60.41666667,  64.375     ,
#         68.33333333,  72.29166667,  76.25      ,  80.20833333,
#         84.16666667,  88.125     ,  92.08333333,  96.04166667,
#        100.        ])

# %% [markdown]
# <font size = 6>To change or format plot</font>

# %%
x = np.linspace(5,100,25)
y = np.linspace(10,1000,25)
plt.plot(x,y,'r')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('First Plot')
plt.show()

# %%
x = np.arange(0,10,1)
y = 2*x+5
plt.plot(x,y,linewidth=2,linestyle=':',color='#2a9d8f',alpha=0.5,marker='o')
plt.title('Line plot demo')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(['line1'],loc='best')
plt.grid(True)
plt.show()

# %%
x = np.linspace(5,100,25)
y = np.linspace(10,1000,25)
plt.plot(x,y,'r*')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('First Plot')
plt.show()

# %%
x = np.linspace(5,100,25)
y = np.linspace(10,1000,25)
plt.plot(x,y,'r*')
plt.plot(x,y*2,'g+')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs Profit in 2022')
plt.show()

# %% [markdown]
# <font size = 6>Above representation is not proper representation<br>
# to tackle this we use subplot</font>

# %% [markdown]
# ## Figures and Subplots
#
# You often need to create multiple plots in the same figure.
#
#
# ```matplotlib``` has the concept of **figures and subplots** using which you can create *multiple subplots inside the same figure*.
#
# To create multiple plots in the same figure, you can use the method ```plt.subplot(nrows, ncols, nsubplot)```.

# %%
x = np.linspace(5,100,25)
y = np.linspace(10,1000,25)
plt.subplot(1,2,1)
plt.plot(x,y,'r*')
plt.subplot(1,2,2)
plt.plot(x,y*2,'g+')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs Profit in 2022')
plt.show()

# %%
x = np.linspace(5,100,25)
y = np.linspace(10,1000,25)
plt.subplot(2,1,1)
plt.plot(x,y,'r*')
plt.subplot(2,1,2)
plt.plot(x,y*2,'g+')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
x = np.linspace(5,100,25)
y = np.linspace(10,1000,25)
plt.figure(figsize=(7,7))
plt.subplot(2,1,1)
plt.plot(x,y,'r*')
plt.subplot(2,1,2)
plt.plot(x,y*2,'g+')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
x = np.linspace(5,100,25)
y = np.linspace(10,1000,25)
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
plt.plot(x,y,'r*')
plt.subplot(2,2,2)
plt.plot(x,y*2,'g+')
plt.subplot(2,2,3)
plt.plot(x,y*3,'b^')
plt.subplot(2,2,4)
plt.plot(x,y*4,'y--')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
x = np.linspace(1,10,100)
y = np.log(x)
plt.figure(1)
plt.subplot(1,2,1)
plt.title('y=log(x)')
plt.plot(x,y)
plt.subplot(1,2,2)
plt.title('y=log(x**2)')
plt.plot(x,y**2)
plt.show()

# %% [markdown]
# ## Types of Plots

# %% [markdown]
# **1. Line Plot**<br>
# Line plot can be used when we are trying to get the trends over a period of time, eg. Unemployment in India over the last 10 years.

# %% [markdown]
# **2. Bar Chart**<br>
# When comparing various categories on the same variable, we use bar plots

# %%
data = {
    'Data Science':20,
    'Machine Learning':15,
    'Full Stack':30,
    'Python':35
}
courses = list(data.keys())
values = list(data.values())

plt.bar(courses,values, color='orange',width=0.3)

plt.show()

# %%
data = {
    'Data Science':20,
    'Machine Learning':15,
    'Full Stack':30,
    'Python':35
}
courses = list(data.keys())
values = list(data.values())

colors = ['#2a9d8f','#e9c46a','#f4a261','#e76f51']

plt.bar(courses,values, color= colors,width=0.5)
plt.show()

# %%
data = {
    'Data Science':20,
    'Machine Learning':15,
    'Full Stack':30,
    'Python':35
}
courses = list(data.keys())
values = list(data.values())

colors = ['#2a9d8f','#e9c46a','#f4a261','#e76f51']

plt.barh(courses,values, color= colors,height=0.5)
plt.show()

# %%
data = {
    'Data Science':20,
    'Machine Learning':15,
    'Full Stack':30,
    'Python':35
}
courses = list(data.keys())
values = list(data.values())

plt.figure(figsize=(10,5))

colors = ['#2a9d8f','#e9c46a','#f4a261','#e76f51']

plt.bar(courses,values, color=colors,width=0.3)

plt.xlabel('Courses offered')
plt.ylabel('No. of students enrolled')
plt.title('Students enrolled in different courses')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <font size=6>Scatter Plot<br>
# when we compare one variable with multiple subjects.<br>
# ex: a month gets clearer than bar chart. A bar chart would be super long. </font>

# %%
data = pd.read_csv('marketing_data.csv')
data.dropna()
# Out:
#     Marketing Budget (X) (In lakhs)  Actual Sales(Y) (In crores)
# 0                             127.4                         10.5
# 1                             364.4                         21.4
# 2                             150.0                         10.0
# 3                             128.7                          9.6
# 4                             285.9                         17.4
# 5                             200.0                         12.5
# 6                             303.3                         20.0
# 7                             315.7                         21.0
# 8                             169.8                         14.7
# 9                             104.9                         10.1
# 10                            297.7                         21.5
# 11                            256.4                         16.6
# 12                            249.1                         17.1
# 13                            323.1                         20.7
# 14                            223.0                         15.5
# 15                            235.0                         13.5
# 16                            200.0                         12.5

# %%
X =  data['Marketing Budget (X) (In lakhs)']
Y =  data['Actual Sales(Y) (In crores)']

plt.scatter(x,y,s=100,c='#e9c46a',marker='o')
plt.xlabel('Marketing Budget (X) (In lakhs)')
plt.ylabel('Actual Sales (Y) (In crores)')
plt.show()

# %%
a = [10,20,30,40,50,60,70,80]
b = [5,3,2,5,6,1,4,2]
x = [1,2,3,4,3,2,1,2]
plt.scatter(a,b, color='#2a9d8f',edgecolor='r',s=300,marker='o',alpha=0.5) # type: ignore
plt.scatter(a,x, color='#e9c46a',s=400,marker='4',alpha=1) # type: ignore
plt.legend(['b','x'],loc='best')
plt.title('Scatter plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %% [markdown]
# <font size=6>To save visualization:<br>
# plt.savefig('name_of_file.png')</font>

# %% [markdown]
# <font size=6>Histogram Plot</font>

# %%
market_df = pd.read_csv('market_fact.csv')
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market_df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
plt.hist(market_df['Sales'],color='#016170')
plt.xlabel('Sales')
plt.show()

# %%
numbers = [10,12,16,19,12,20,26,28,30,38,35,34,60,68,64,62,70,78,75,79,85,84,95]
plt.hist(numbers, bins=[0,20,40,60,80,100],edgecolor='#00e0c6',color='#016170')
plt.title('Numbers frequency')
plt.xlabel('numbers range')
plt.ylabel('Frequencies')
plt.legend(['line'],loc='best')
plt.show()

# %% [markdown]
# <font size=6>Box Plot<br>
# helps in outer analysis</font>

# %%
plt.boxplot(market_df['Sales'])
plt.show()

# %% [markdown]
# <font size=6>to see box plot properly we use yscale('log')</font>

# %%
plt.figure(figsize=(7,5))
plt.boxplot(market_df['Sales'])
plt.yscale('log')
plt.show()

# %%
total = [20,4,1,30,20,10,20,70,30,10]
order = [10,3,1,15,17,2,30,44,2,1]
discount = [30,10,20,5,10,20,50,60,20,40]
data = list([total,order,discount])
plt.boxplot(data,showmeans=True)
plt.title('Box plot')
plt.grid(True)
plt.show()

# %% [markdown]
# <font size=6>Viloin Plot<br>
# generally used to describe a numerical variable one/several row.</font>

# %%
total = [20,4,1,30,20,10,20,70,30,10]
order = [10,3,1,15,17,2,30,44,2,1]
discount = [30,10,20,5,10,20,50,60,20,40]
data = list([total,order,discount])
plt.violinplot(data,showmeans=True)
plt.title('Box plot')
plt.grid(True)
plt.show()

# %% [markdown]
# <font size=6>Pie Chart</font>

# %%
label = ['dog','cat','wolf','lion']
sizes = [50,45,60,80]
plt.pie(sizes,labels=label,autopct='%1.1f%%',shadow=True,startangle=90)
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# <font size=6>Doughnut Chart</font>

# %%
group_name = ['grp1','grp2','grp3']
group_size = [20,30,50]
size_centre = [5]
pie1 = plt .pie(group_size,labels=group_name,radius=1.5)
pie2 =plt.pie(size_centre,radius=1,colors='w')
plt.show()

# %% [markdown]
# <font size=6>Area Chart</font>

# %%
x = range(1,15)
y = [1,4,6,8,4,5,3,2,4,1,5,6,8,7]

plt.stackplot(x,y,colors='Black',alpha=0.5) # type: ignore
plt.show()

# %% [markdown]
# <font size=6>To merge line and area plot</font>

# %%
x = range(1,15)
y = [1,4,6,8,4,5,3,2,4,1,5,6,8,7]

plt.stackplot(x,y,colors='Black',alpha=0.5) # type: ignore
plt.plot(x,y,color='g')
plt.show()

# %% [markdown]
# <font size=6>Visualisatioin on dataset</font>

# %% [markdown]
# # Visualizations with Seaborn

# %% [markdown]
# - In the world of Analytics, the best way to get insights is by visualizing the data.
# - We have already used Matplotlib, a 2D plotting library that allows us to plot different graphs and charts.
# - Another complimentary package that is based on this data visualization library is Seaborn, which provides a high-level interface to draw statistical graphics.

# %% [markdown]
# **Seaborn**
#
# - Is a python data visualization library for statistical plotting
# - Is based on matplotlib (built on top of matplotlib)
# - Is designed to work with NumPy and pandas data structures
# - Provides a high-level interface for drawing attractive and informative statistical graphics.
# - Comes equipped with preset styles and color palettes so you can create complex, aesthetically pleasing charts with a few lines of code.
#
# - Seaborn is built on top of Python's core visualization library matplotlib, but it's meant to serve as a complement, not a replacement.
# - In most cases, we’ll still use matplotlib for simple plotting
# - Seaborn helps resolve the two major problems faced by Matplotlib, the problems are −
#     - Default Matplotlib parameters
#     - Working with dataframes

# %%
import seaborn as sns

# %% [markdown]
# We are going to use 2 built in functions of Seaborn to make our visualizations :
#
# - load_dataset()
# - get_dataset_names()

# %%
sns.set()

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
sns.set()

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **Scatter Plot**
# - A scatterplot is the most common example of visualizing relationships between two variables.
# - It depicts the joint distribution of two variables using a cloud of points, where each point represents an observation in the dataset.
# - This depiction allows the eye to infer a substantial amount of information about whether there is any meaningful relationship between them.

# %%
sns.relplot(x='total_bill',y='tip',data=tips,kind='scatter')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=tips,kind='scatter',hue='sex')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=tips,kind='scatter',hue='sex',col='sex')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=tips,kind='scatter',hue='smoker',col='sex')
plt.show()

# %% [markdown]
# **Line Plot**
#
# - Suitable when we want to understand change in one variable as a function of time or some other continuous variable.
# - It depicts the relationship between continuous as well as categorical values in a continuous data point format.

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.relplot(x='year', y='passengers', data=flights, kind='line')
plt.show()

# %%
sns.lineplot(x='year', y='passengers',data=flights)
plt.show()

# %%
sns.relplot(x='year', y='passengers', data=flights, kind='line', hue='month')
plt.show()

# %% [markdown]
# # creating subplot

# %%
sns.relplot(x='year', y='passengers', data=flights, kind='line', hue='month',col='month')
plt.show()

# %% [markdown]
# ### Categorical Data Plotting
#
# - Now we’ll see the relationship between two variables of which one would be categorical.
# - There are several ways to visualize a relationship involving categorical data in seaborn.
# - catplot() - it gives a unified approach to plot different kind of categorical plots in seaborn

# %% [markdown]
# ### Categorical Distribution Plots
#
# - As the size of the dataset grows, categorical scatter plots become limited in the information they can provide about the distribution of values within each category.
# - In such cases we can use several approaches for summarizing the distributional information in ways that facilitate easy comparisons across the category levels.
# - We use distribution plots to get a sense for how the variables are distributed.

# %% [markdown]
# ### Box Plot
#
# - It is also named a box-and-whisker plot.
# - Boxplots are used to visualize distributions. This is very useful when we want to compare data between two groups.
# - Box Plot is the visual representation of the depicting groups of numerical data through their quartiles.
# - Boxplot is also used to detect the outliers in data set.

# %%
sns.catplot(x='time', y='total_bill', data=tips, kind='box', hue='time')
plt.show()

# %%
sns.catplot(x='time', y='total_bill', data=tips, kind='box', hue='smoker',col='sex')
plt.show()

# %%
sns.boxplot(x='sex', y='total_bill', data=tips, hue='smoker')
plt.show()

# %% [markdown]
# ### Violin Plot
#
# - It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.
# - It is really close from a boxplot, but allows a deeper understanding of the density.

# %% [markdown]
# - The density is mirrored and flipped over and the resulting shape is filled in, creating an image resembling a violin.
# - The advantage of a violin plot is that it can show nuances in the distribution that aren’t perceptible in a boxplot.
# - On the other hand, the boxplot more clearly shows the outliers in the data.
# - Violins are particularly adapted when the amount of data is huge and showing individual observations gets impossible.

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.catplot(x = 'species', y = 'sepal_width', data = iris, kind='violin', col = 'species')
plt.show()

# %%
sns.violinplot(x='species', y='sepal_width', data = iris)
plt.show()

# %% [markdown]
# ### Countplots
#
# They show the count of observations in each column mentioned using a bar chart. It is like a histogram but for categorical variables.

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x = 'class', data = titanic)
plt.show()

# %%
sns.countplot(x = 'class', data = titanic, hue='who')
plt.show()

# %% [markdown]
# ## Visualizing Data Distributions

# %% [markdown]
# ### Distplot
#
# Plots a univariate distribution of observations

# %%
market_df = pd.read_csv('market_fact.csv')
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
sns.distplot(market_df['Shipping_Cost'])
plt.show()
# Out:
# /Users/ritikramesh/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Jointplot
#
# Used to plot two variables with Bivariate scatterplot and Univariate Histogram in the same plot.

# %%
sns.jointplot(market_df['Sales'], market_df['Profit'])
plt.show()

# %%
# remove points having extreme values
market_df = market_df[(market_df.Profit < 10000) & (market_df.Sales < 20000)]

sns.jointplot(market_df['Sales'], market_df['Profit'])
plt.show()

# %% [markdown]
# ## Pairplots
#
# To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species')
plt.show()

# %%
sns.pairplot(iris[['sepal_length','sepal_width']])
plt.show()

# %% [markdown]
# ## Regplot
#
# Plot data and a linear regression model fit.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
data = sns.load_dataset('mpg')

sns.regplot(x='mpg', y='acceleration', data = data)
plt.show()

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# ## lmplot
#
# Plot data and regression model fits across a FacetGrid.

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='smoker', hue='smoker')
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg = True, col='sex', hue='sex')
plt.show()

# %% [markdown]
# ## Density Chart
#
# A density plot is a representation of the distribution of a numeric variable. Density plots are used to study the distribution of one or a few variables.

# %%
sns.displot(x='total_bill',data=tips)
plt.show()

# %%
sns.distplot(tips['total_bill'])
plt.show()

# %%
sns.kdeplot(x='total_bill',data=tips)
plt.show()

# %%
sns.kdeplot(x='sepal_length', data=iris)
plt.show()

# %%
sns.kdeplot(x='sepal_width', data=iris)
plt.show()

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Heatmap

# %%
corr = iris.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %%
sns.heatmap(corr, cmap='coolwarm')
plt.show()

# %%
sns.heatmap(corr, cmap='Blues')
plt.show()

# %% [markdown]
# **Possible values are:** Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG,
# PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r,
# YlOrBr, YlOrBr_r, YlOrRd etc
